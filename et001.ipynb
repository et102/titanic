# %% [markdown]
# 1. PassengerID - A column added by Kaggle to identify each row and make submissions easier
# 2. Survived - Whether the passenger survived or not and the value we are predicting (0=No, 1=Yes)
# 3. Pclass - The class of the ticket the passenger purchased (1=1st, 2=2nd, 3=3rd)
# 4. Sex - The passenger's sex
# 5. Age - The passenger's age in years
# 6. SibSp - The number of siblings or spouses the passenger had aboard the Titanic
# 7. Parch - The number of parents or children the passenger had aboard the Titanic
# 8. Ticket - The passenger's ticket number
# 9. Fare - The fare the passenger paid
# 10. Cabin - The passenger's cabin number
# 11. Embarked - The port where the passenger embarked (C=Cherbourg, Q=Queenstown, S=Southampton)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('data/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - Null values: Age, Cabin and Embarked

# %% [markdown]
# ### How many Survivors?

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ##### [Insights]
# Out of 891 passengers in training set, only around 350 survived i.e Only 38.4% of the total training set survived the crash.　Need to dig deeper for more insights

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ## *Analysis steps:*
#
# ### **Part 1 Exploratory Data Analysis(EDA):**
# - feature analysis
# - feature correlation
#
# ### **Part 2 Data cleaning and Feature engineering**
# - missing data
# - FE: "age", "fare", "Parch", "SibSp"
# - FE: String Values into Numeric
# ### **Part 3 Modeling**
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Part 1 Exploratory Data Analysis(EDA):
# ### Feature Analysis

# %% [markdown]
# ### Sex

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# ##### [Insights]
# The number of female survivors is twice the number of male survivors even with higher number of males in total.
#
# Survival rate:
# Men : 18-19%
# Women: 75%
#
# Is age the best feature for modeling?

# %% [markdown]
# ### P-Class

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_e8c31_row0_col0, #T_e8c31_row1_col1, #T_e8c31_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e8c31_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_e8c31_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_e8c31_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_e8c31_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_e8c31_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_e8c31_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_e8c31_row3_col0, #T_e8c31_row3_col1, #T_e8c31_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e8c31">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_e8c31_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e8c31_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# ##### [Insights]
#
# Survival Rate of each Pclass
# 1: 63%
# 2: 48%
# 3: 25%
#
# The beter the class, the higher the survival rate

# %% [markdown]
# ### Sex & P-Class

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f4ae7_row0_col0, #T_f4ae7_row0_col1, #T_f4ae7_row0_col3, #T_f4ae7_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f4ae7_row0_col2, #T_f4ae7_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_f4ae7_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_f4ae7_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_f4ae7_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_f4ae7_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_f4ae7_row2_col1, #T_f4ae7_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_f4ae7_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_f4ae7_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_f4ae7_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_f4ae7_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# ##### [Insights]
# - Survival rate of Women from Pclass1 is about 95-96%
# - Survival rate of Women is higher than men in each class, which suggests that woemn is given higher priority of rescuing

# %% [markdown]
# ### Age

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# ##### [Insights]
# 1)The number of children (Age below 10) increases with "decreasing" Pclass
# 2)Survival chances for Passenegers aged 20-50 from class1 is higher( survival rate of Women > men)
# 3)For males, the survival chances decreases with an increase in age.

# %% [markdown]
# ### Embarked Port

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_454f6_row0_col0, #T_454f6_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_454f6_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_454f6_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_454f6_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_454f6_row0_col4, #T_454f6_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_454f6_row1_col0, #T_454f6_row3_col0, #T_454f6_row3_col1, #T_454f6_row3_col2, #T_454f6_row3_col3, #T_454f6_row3_col4, #T_454f6_row4_col0, #T_454f6_row4_col2, #T_454f6_row4_col3, #T_454f6_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_454f6_row1_col1, #T_454f6_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_454f6_row1_col3, #T_454f6_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_454f6_row2_col0, #T_454f6_row5_col1 {
#   background-color: #e6f266;
# ...

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %% [markdown]
# ##### [Insights] The chances for survival for Port C is highest around 0.55 while it is lowest for S.

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# [Insights]
# 1)Higher number of passenegers boarded from S.
# 2)The majority of the rich and the poor is in Pclass3
# 3)95% of passengers boarded from port Q were in class3.

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# ##### [Insights]
# The survival rate of port S Passengers in Pclass is very low for both men and women. (money and luck)

# %% [markdown]
# ### SibSip (Sibling, spouse)

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_ba946_row0_col0, #T_ba946_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_ba946_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_ba946_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_ba946_row2_col0, #T_ba946_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_ba946_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_ba946_row3_col0, #T_ba946_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_ba946_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_ba946_row5_col0, #T_ba946_row5_col1, #T_ba946_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ba946_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_ba946">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
# ...

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9acb7_row0_col0, #T_9acb7_row0_col1, #T_9acb7_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_9acb7_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_9acb7_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_9acb7_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_9acb7_row2_col0, #T_9acb7_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_9acb7_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_9acb7_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_9acb7_row3_col0, #T_9acb7_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_9acb7_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_9acb7_row4_col0, #T_9acb7_row4_col1, #T_9acb7_row5_col0, #T_9acb7_row5_col1, #T_9acb7_row5_col2, #T_9acb7_row6_col0, #T_9acb7_row6_col1 {
#   background-color: #ffff66;
# ...

# %%
sns.factorplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
plt.show()

# %% [markdown]
# [Insights]
# - Passtergers with spouse or one sibling has the highest survival rate as he or she get help. However, The survival rate decaeases with the number of sibling. The reason could be P-Class(lower income) or too many siblings who are difficult to prioritize

# %% [markdown]
# ### Parch

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_67d1b_row0_col0, #T_67d1b_row0_col1, #T_67d1b_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_67d1b_row1_col0 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_67d1b_row1_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_67d1b_row1_col2 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_67d1b_row2_col0 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_67d1b_row2_col1 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_67d1b_row2_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_67d1b_row3_col0, #T_67d1b_row4_col1, #T_67d1b_row5_col0, #T_67d1b_row5_col1, #T_67d1b_row6_col0, #T_67d1b_row6_col1, #T_67d1b_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_67d1b_row3_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_67d1b_row3_col2, #T_67d1b_row4_col0, #T_67d1b_row4_col2 {
#   background-color: #fefe66;
# ...

# %%
sns.factorplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.show()

# %% [markdown]
# [Insights]
# - Similar to "siblings", passengers with siblings or parents have higher survival rate but the rate decrease with siblings.

# %% [markdown]
# ### Fare

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# ### Correlation Between The Features (only numeric features)

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# [Insights]
# - Parch and sibSp (0.41) are highly correlated which suggests that we can drop redundant features. (MultiColinearity: containing the same or similar information)

# %% [markdown]
# ### Part 2 Data cleaning and Feature engineering
# ### Data cleaning

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - Features with Nan: Age, Cabin, Embarked

# %%
data['Embarked'].fillna('S',inplace=True)
data.Embarked.isnull().any()# Finally No NaN values
# Out:
# False

# %% [markdown]
# - Age feature has 177 null values. To replace NaN values, we can assign them the mean age or use name (salutation) to give better age

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_ace88_row0_col0, #T_ace88_row0_col1, #T_ace88_row0_col3, #T_ace88_row0_col4, #T_ace88_row0_col5, #T_ace88_row0_col7, #T_ace88_row0_col8, #T_ace88_row0_col12, #T_ace88_row0_col15, #T_ace88_row0_col16, #T_ace88_row1_col2, #T_ace88_row1_col6, #T_ace88_row1_col9, #T_ace88_row1_col10, #T_ace88_row1_col11, #T_ace88_row1_col13, #T_ace88_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ace88_row0_col2, #T_ace88_row0_col6, #T_ace88_row0_col9, #T_ace88_row0_col10, #T_ace88_row0_col11, #T_ace88_row0_col13, #T_ace88_row0_col14, #T_ace88_row1_col0, #T_ace88_row1_col1, #T_ace88_row1_col3, #T_ace88_row1_col4, #T_ace88_row1_col5, #T_ace88_row1_col7, #T_ace88_row1_col8, #T_ace88_row1_col12, #T_ace88_row1_col15, #T_ace88_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ace88">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
# recategorize Mr, Miss, Master, Mrs Other
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
# recheck average age
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

#check null value
data.Age.isnull().any() #So no null values left finally
# Out:
# False

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# Initial          0
# dtype: int64

# %% [markdown]
# ### Feature Engineering
# ### Age (Numberic -> Categorical)

# %%
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
#checking the number of passenegers in each band
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_bcc66_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_bcc66_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_bcc66_row2_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_bcc66_row3_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_bcc66_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bcc66">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcc66_level0_col0" class="col_heading level0 col0" >Age_band</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcc66_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bcc66_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
#       <th id="T_bcc66_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bcc66_row1_col0" class="data row1 col0" >325</td>
#     </tr>
#     <tr>
# ...

# %%
sns.factorplot('Age_band','Survived',data=data,col='Pclass')
plt.show()

# %% [markdown]
# ### Family Size (Parch and SibSp)

# %%
data['Family_Size']=0
data['Family_Size']=data['Parch']+data['SibSp']#family size
data['Alone']=0
data.loc[data.Family_Size==0,'Alone']=1

#data['Family_Size']

#f,ax=plt.subplots(1,2,figsize=(18,6))
sns.factorplot('Family_Size','Survived',data=data,ax=ax[0])
#ax[0].set_title('Family_Size vs Survived')
sns.factorplot('Alone','Survived',data=data,ax=ax[1])
ax[1].set_title('Alone vs Survived')
plt.show()

# %% [markdown]
# [insights]
# - For passengers who are alone, the survival rate is relatively low.
# - For family size > 4,the chances decrease

# %%
sns.factorplot('Alone','Survived',data=data,hue='Sex',col='Pclass')
plt.show()

# %% [markdown]
# [insights]
# - passengers who are alone are indeed more likely to die
# - however, females in Pcalss3 have higher survival rate

# %% [markdown]
# ### Fare_range

# %%
data['Fare_Range']=pd.qcut(data['Fare'],4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_b2786_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_b2786_row1_col0 {
#   background-color: #b9dc66;
#   color: #000000;
# }
# #T_b2786_row2_col0 {
#   background-color: #54aa66;
#   color: #f1f1f1;
# }
# #T_b2786_row3_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b2786">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2786_level0_col0" class="col_heading level0 col0" >Survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare_Range</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2786_level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#       <td id="T_b2786_row0_col0" class="data row0 col0" >0.197309</td>
#     </tr>
#     <tr>
#       <th id="T_b2786_level0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
# ...

# %%
# change categorical feature to numberical one
data['Fare_cat']=0
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
sns.factorplot('Fare_cat','Survived',data=data,hue='Sex')
plt.show()

# %% [markdown]
# ### String Values --> Numeric

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %% [markdown]
# ### Drop Reduladant Features

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)

# %% [markdown]
# ### Recheck Correlation

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
